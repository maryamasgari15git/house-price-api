# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.11.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    6.3.0
# certifi                   2025.10.5
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# ipykernel                 7.1.0
# ...

# %%
pip install flask
# Out:
# ...
#
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------- ----------------------- 2/5 [click]
#    -------------------------------- ------- 4/5 [flask]
#    ---------------------------------------- 5/5 [flask]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip show flask
# Out:
# Name: Flask
# Version: 3.1.2
# Summary: A simple framework for building complex web applications.
# Home-page:
# Author:
# Author-email:
# License-Expression: BSD-3-Clause
# Location: C:\Users\root\Documents\API_Project\venv\Lib\site-packages
# Requires: blinker, click, itsdangerous, jinja2, markupsafe, werkzeug
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python api.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\root\Documents\API_Project\api.py", line 2, in <module>
#     import joblib
# ModuleNotFoundError: No module named 'joblib'

# %%
# !pip install joblib
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python api.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\root\Documents\API_Project\api.py", line 8, in <module>
#     model = joblib.load("house_price_model.pkl")
#   File "C:\Users\root\Documents\API_Project\venv\Lib\site-packages\joblib\numpy_pickle.py", line 749, in load
#     obj = _unpickle(
#         fobj,
#     ...<2 lines>...
#         mmap_mode=validated_mmap_mode,
#     )
#   File "C:\Users\root\Documents\API_Project\venv\Lib\site-packages\joblib\numpy_pickle.py", line 626, in _unpickle
#     obj = unpickler.load()
#   File "C:\Users\root\anaconda3\Lib\pickle.py", line 1256, in load
#     dispatch[key[0]](self)
#     ~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\root\anaconda3\Lib\pickle.py", line 1581, in load_stack_global
#     self.append(self.find_class(module, name))
#                 ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
#   File "C:\Users\root\anaconda3\Lib\pickle.py", line 1622, in find_class
#     __import__(module, level=0)
#     ~~~~~~~~~~^^^^^^^^^^^^^^^^^
# ...
